# %%
import pandas as pd

df = pd.read_csv('/content/self assessment data-1.csv')

print(df.to_string()) 
#K Means Clustering
# Out:
#        a     b
# 0   10.9  12.6
# 1    2.3   8.4
# 2    8.4  12.6
# 3   12.1  16.2
# 4    7.3   8.9
# 5   23.4  11.3
# 6   19.7  18.5
# 7   17.1  17.2
# 8    3.2   3.4
# 9    1.3  22.8
# 10   2.4   6.9
# 11   2.4   7.1
# 12   3.1   8.3
# 13   2.9   6.9
# 14  11.2   4.4
# 15   8.3   8.7
# 16   1.2  19.5
# 17   0.5  20.0

# %%
import pandas as pd

df = pd.read_csv('/content/self_assessment_data-2.csv')

print(df)
#KNN because pm1 and pm2 are numeric
# Out:
#     PM 1  PM 2    Status
# 0    0.8   6.3  Rejected
# 1    1.4   8.1  Rejected
# 2    2.1   7.4  Rejected
# 3    2.6  14.3  Accepted
# 4    6.8  12.6  Rejected
# 5    8.8   9.8  Accepted
# 6    9.2  11.6  Rejected
# 7   10.8   9.6  Accepted
# 8   11.8   9.9  Accepted
# 9   12.4   6.5  Accepted
# 10  12.8   1.1  Rejected
# 11  14.0  19.9  Rejected
# 12  14.2  18.5  Rejected
# 13  15.6  17.4  Rejected
# 14  15.8  12.2  Rejected
# 15  16.6   6.7  Accepted
# 16  17.4   4.5  Accepted
# 17  18.2   6.9  Accepted
# 18  19.0   3.4  Rejected
# 19  19.6  11.1  Accepted
